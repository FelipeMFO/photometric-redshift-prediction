# %% [markdown]
# ## This notebook applies h2o auto ML techniques to predict Redshift through linear regression models.

# %%
# %load_ext autoreload
# %autoreload 2
import os 
import sys
import time
import h2o

import pandas as pd

from sklearn.metrics import mean_squared_error
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
module_path = os.path.abspath(os.path.join('..','..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.modeling.functions_autoML import auto_ML, save_aml_models, gen_predictions

# %%
pd.set_option("display.max_rows", 6)

# %%
df = pd.read_pickle("../../data/structured/df.pkl")
df
# Out:
#                                                        desg  \
# ID
# SN10001   [[0.0, 2.326, 4.792], [2.0, 4.617, 2.249], [9....
# SN100023  [[6.984000000004016, 5.679, 6.387], [7.9920000...
# SN10005   [[10.027000000001863, 4.996, 8.081], [33.94500...
# ...                                                     ...
# SN99921   [[0.0, 8.327, 4.797], [2.0, 9.834, 2.261], [9....
# SN99946   [[11.961000000002969, 1.526, 5.683], [13.05500...
# SN9999    [[8.942000000002736, 3.615, 5.646], [18.930000...
#
#                                                        desi  \
# ID
# SN10001   [[0.031000000002677552, 8.672, 5.439], [2.1560...
# SN100023  [[7.00800000000163, 4.698, 7.145], [8.02300000...
# SN10005   [[0.015000000006693881, 0.2977, 2.206], [18.94...
# ...                                                     ...
# SN99921   [[0.031000000002677552, 22.78, 5.454], [2.1560...
# SN99946   [[0.01599999999598367, 4.95, 3.147], [3.034999...
# SN9999    [[0.0, 11.54, 6.741], [7.9650000000037835, 4.9...
#
#                                                        desr  \
# ID
# SN10001   [[0.01600000000325963, 8.834, 5.339], [2.13999...
# SN100023  [[0.0, 16.04, 17.59], [6.992000000005646, 19.8...
# SN10005   [[0.0, 1.033, 1.325], [13.015000000006694, 0.4...
# ...                                                     ...
# SN99921   [[0.01600000000325963, 26.73, 5.361], [2.13999...
# SN99946   [[0.0, 0.4826, 2.129], [2.995999999999185, 0.7...
# SN9999    [[8.95400000000518, 0.9289, 4.33], [18.9380000...
#
#                                                        desz  \
# ID
# SN10001   [[0.06199999999807915, 6.026, 4.693], [2.18699...
# SN100023  [[4.121000000006461, 18.01, 3.601], [7.0230000...
# SN10005   [[0.03500000000349246, 1.826, 3.029], [48.875,...
# ...                                                     ...
# SN99921   [[0.06199999999807915, 15.19, 4.7], [2.1869999...
# SN99946   [[0.03899999999703141, 1.045, 2.483], [12.0389...
# SN9999    [[7.973000000005413, 3.831, 6.472], [18.954000...
#
#                                                       Xaxis  \
# ID
# SN10001   [0.0, 1.1313535353535435, 2.262707070707087, 3...
# SN100023  [0.0, 1.3437474747475018, 2.6874949494950036, ...
# SN10005   [0.0, 1.0381919191919462, 2.0763838383838924, ...
# ...                                                     ...
# SN99921   [0.0, 1.2923333333333222, 2.5846666666666445, ...
# SN99946   [0.0, 1.3626161616161374, 2.725232323232275, 4...
# SN9999    [0.0, 1.383727272727287, 2.767454545454574, 4....
#
#                                                     desg_GP  \
# ID
# SN10001   ([0.0, 0.818888888888886, 1.637777777777772, 2...
# SN100023  ([6.984000000004016, 8.256929292933277, 9.5298...
# SN10005   ([10.027000000001863, 10.782565656567513, 11.5...
# ...                                                     ...
# SN99921   ([0.0, 1.1299292929293416, 2.2598585858586833,...
# SN99946   ([11.961000000002969, 13.202242424245336, 14.4...
# SN9999    ([8.942000000002736, 10.114111111113816, 11.28...
#
#                                                     desi_GP  \
# ID
# SN10001   ([0.031000000002677552, 1.141676767679467, 2.2...
# SN100023  ([7.00800000000163, 8.189737373738987, 9.37147...
# SN10005   ([0.015000000006693881, 1.0530404040470573, 2....
# ...                                                     ...
# SN99921   ([0.031000000002677552, 1.3230202020228414, 2....
# SN99946   ([0.01599999999598367, 1.3782121212081455, 2.7...
# SN9999    ([0.0, 1.383727272727287, 2.767454545454574, 4...
#
#                                                     desr_GP  \
# ID
# SN10001   ([0.01600000000325963, 1.076565656568908, 2.13...
# SN100023  ([0.0, 0.8994242424242942, 1.7988484848485884,...
# SN10005   ([0.0, 1.0281717171717606, 2.056343434343521, ...
# ...                                                     ...
# SN99921   ([0.01600000000325963, 1.3080606060638358, 2.6...
# SN99946   ([0.0, 1.362181818181816, 2.724363636363632, 4...
# SN9999    ([8.95400000000518, 10.247202020207146, 11.540...
#
#                                                     desz_GP  \
# ID
# SN10001   ([0.06199999999807915, 1.1927272727253795, 2.3...
# SN100023  ([4.121000000006461, 5.423121212127635, 6.7252...
# SN10005   ([0.03500000000349246, 1.0222929292964054, 2.0...
# ...                                                     ...
# SN99921   ([0.06199999999807915, 1.2726666666647435, 2.4...
# SN99946   ([0.03899999999703141, 1.4012222222192594, 2.7...
# SN9999    ([7.973000000005413, 9.155171717177092, 10.337...
#
#                                                    wavelets  ...        f14  \
# ID                                                           ...
# SN10001   [9.251771363349247, 8.972870155014132, 8.79160...  ...   6.048710
# SN100023  [12.22728787505526, 11.357060718395505, 10.716...  ...  33.710197
# SN10005   [2.000004411755352, 2.000003547336676, 2.00000...  ... -26.554909
# ...                                                     ...  ...        ...
# SN99921   [14.025137598441496, 16.23859348218353, 17.966...  ...  30.582545
# SN99946   [3.7693816011787566, 5.06053615747151, 6.78000...  ...  95.149318
# SN9999    [4.850644791493887, 5.421672218074873, 6.00573...  ...  -0.255811
#
#                  f15        f16        f17         f18        f19        f20  \
# ID
# SN10001   -11.165995  23.954122  18.206974    6.125705   9.448973  -0.077951
# SN100023  -11.581964  28.655932  19.743617    4.619561  37.266783 -16.595923
# SN10005    15.768490  16.436792  17.114796  -20.292959 -24.222562 -11.295566
# ...              ...        ...        ...         ...        ...        ...
# SN99921   -38.454611  33.695746  32.105618   -3.304426  32.695384 -16.237329
# SN99946   183.911735  62.540835  28.895779 -271.089840  54.766397  39.959973
# SN9999     27.946895  12.027626 -11.213953    2.524683  -3.917775   7.161204
#
#           type  type_bool  REDSHIFT_SPEC
# ID
# SN10001     II      False        0.59162
# SN100023    II      False        0.79264
# SN10005     Ia       True        1.08327
# ...        ...        ...            ...
# SN99921     II      False        0.69650
# SN99946     Ia       True        0.40625
# SN9999      II      False        0.54982
#
# [21291 rows x 33 columns]

# %% [markdown]
# ### Auto ML 5 models

# %%
start_time = time.time()

aml = auto_ML(df, 5, .5)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Checking whether there is an H2O instance running at http://localhost:54323 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         13 mins 07 secs
# H2O_cluster_timezone:       America/Sao_Paulo
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.1.3
# H2O_cluster_version_age:    2 months and 24 days
# H2O_cluster_name:           H2O_from_python_fmoliveira_wvcquq
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.871 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54323
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.6.9 final
# --------------------------  ------------------------------------------------------------------
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# Leaderboard:
# <table>
# <thead>
# <tr><th>model_id                                           </th><th style="text-align: right;">  mean_residual_deviance</th><th style="text-align: right;">     rmse</th><th style="text-align: right;">       mse</th><th style="text-align: right;">      mae</th><th style="text-align: right;">    rmsle</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_AllModels_AutoML_20201222_232526   </td><td style="text-align: right;">              0.00806606</td><td style="text-align: right;">0.0898112</td><td style="text-align: right;">0.00806606</td><td style="text-align: right;">0.0687872</td><td style="text-align: right;">0.0520735</td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_AutoML_20201222_232526</td><td style="text-align: right;">              0.00832846</td><td style="text-align: right;">0.0912604</td><td style="text-align: right;">0.00832846</td><td style="text-align: right;">0.0703246</td><td style="text-align: right;">0.0528456</td></tr>
# <tr><td>DRF_1_AutoML_20201222_232526                       </td><td style="text-align: right;">              0.00869452</td><td style="text-align: right;">0.0932444</td><td style="text-align: right;">0.00869452</td><td style="text-align: right;">0.0720666</td><td style="text-align: right;">0.0540014</td></tr>
# <tr><td>XGBoost_3_AutoML_20201222_232526                   </td><td style="text-align: right;">              0.00912034</td><td style="text-align: right;">0.0955004</td><td style="text-align: right;">0.00912034</td><td style="text-align: right;">0.074035 </td><td style="text-align: right;">0.0553491</td></tr>
# <tr><td>XGBoost_2_AutoML_20201222_232526                   </td><td style="text-align: right;">              0.00966219</td><td style="text-align: right;">0.0982965</td><td style="text-align: right;">0.00966219</td><td style="text-align: right;">0.0745544</td><td style="text-align: right;">0.0569475</td></tr>
# <tr><td>XGBoost_1_AutoML_20201222_232526                   </td><td style="text-align: right;">              0.0097778 </td><td style="text-align: right;">0.0988828</td><td style="text-align: right;">0.0097778 </td><td style="text-align: right;">0.0750848</td><td style="text-align: right;">0.057114 </td></tr>
# <tr><td>GLM_1_AutoML_20201222_232526                       </td><td style="text-align: right;">              0.038624  </td><td style="text-align: right;">0.19653  </td><td style="text-align: right;">0.038624  </td><td style="text-align: right;">0.165075 </td><td style="text-align: right;">0.118047 </td></tr>
# </tbody>
# </table>
#
#
# Leader:  Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_AutoML_20201222_232526
#
# No model summary for this model
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0010907657461668554
# RMSE: 0.03302674289370442
# MAE: 0.025236380215375002
# RMSLE: 0.01911988931095091
# R^2: 0.97967080874221
# Mean Residual Deviance: 0.0010907657461668554
# Null degrees of freedom: 2513
# Residual degrees of freedom: 2508
# Null deviance: 134.8890396617478
# Residual deviance: 2.742185085863474
# AIC: -9999.257584319548
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.008912626357440483
# RMSE: 0.09440670716342395
# MAE: 0.07274288565786766
# RMSLE: 0.054205061134228696
# R^2: 0.8338905613177126
# Mean Residual Deviance: 0.008912626357440483
# Null degrees of freedom: 2513
# Residual degrees of freedom: 2508
# Null deviance: 134.9564244916461
# Residual deviance: 22.406342662605375
# AIC: -4718.37685294119
#
#
# --- 20.773753881454468 seconds ---

# %%
save_aml_models(aml)
# Out:
# Model StackedEnsemble_AllModels_AutoML_20201222_231222 saved.
# Model StackedEnsemble_BestOfFamily_AutoML_20201222_231222 saved.
# Model DRF_1_AutoML_20201222_231222 saved.
# Model XGBoost_3_AutoML_20201222_231222 saved.
# Model XGBoost_2_AutoML_20201222_231222 saved.
# Model XGBoost_1_AutoML_20201222_231222 saved.
# Model GLM_1_AutoML_20201222_231222 saved.

# %% [markdown]
# ### Auto ML 50 models
# #### Best model is always StackedEnsemble_AllModels.
# #### It was trained with half of the entire DataFrame and validated with the other half.
# ##### Values set by ` h2o.H2OFrame( df.loc[:,'f1':'REDSHIFT_SPEC'] ).split_frame(ratios=[.5]) `

# %%
start_time = time.time()

aml = auto_ML(df, 50, .5)

print("--- %s seconds ---" % (time.time() - start_time))
print(f'{(time.time() - start_time)/3600} hours training.')
# Out:
# Checking whether there is an H2O instance running at http://localhost:54323 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.11" 2021-04-20; OpenJDK Runtime Environment (build 11.0.11+9-Ubuntu-0ubuntu2.20.04); OpenJDK 64-Bit Server VM (build 11.0.11+9-Ubuntu-0ubuntu2.20.04, mixed mode, sharing)
#   Starting server from /home/felipe/.local/lib/python3.8/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpwvwggq40
#   JVM stdout: /tmp/tmpwvwggq40/h2o_felipe_started_from_python.out
#   JVM stderr: /tmp/tmpwvwggq40/h2o_felipe_started_from_python.err
#   Server is running at http://127.0.0.1:54323
# Connecting to H2O server at http://127.0.0.1:54323 ... successful.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       America/Sao_Paulo
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.1.2
# H2O_cluster_version_age:    14 days, 6 hours and 33 minutes
# H2O_cluster_name:           H2O_from_python_felipe_ewlygy
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.863 Gb
# H2O_cluster_total_cores:    12
# H2O_cluster_allowed_cores:  12
# H2O_cluster_status:         accepting new members, healthy
# H2O_connection_url:         http://127.0.0.1:54323
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.5 final
# --------------------------  ------------------------------------------------------------------
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# Leaderboard:
# <table>
# <thead>
# <tr><th>model_id                                           </th><th style="text-align: right;">  mean_residual_deviance</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">      mse</th><th style="text-align: right;">     mae</th><th style="text-align: right;">      rmsle</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_AllModels_AutoML_20210513_234908   </td><td style="text-align: right;">               0.0195501</td><td style="text-align: right;">0.139822</td><td style="text-align: right;">0.0195501</td><td style="text-align: right;">0.104298</td><td style="text-align: right;">nan        </td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_AutoML_20210513_234908</td><td style="text-align: right;">               0.0199338</td><td style="text-align: right;">0.141187</td><td style="text-align: right;">0.0199338</td><td style="text-align: right;">0.106016</td><td style="text-align: right;">  0.0871648</td></tr>
# <tr><td>GBM_4_AutoML_20210513_234908                       </td><td style="text-align: right;">               0.0218111</td><td style="text-align: right;">0.147686</td><td style="text-align: right;">0.0218111</td><td style="text-align: right;">0.112292</td><td style="text-align: right;">  0.0893228</td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20210513_234908_model_1     </td><td style="text-align: right;">               0.022044 </td><td style="text-align: right;">0.148472</td><td style="text-align: right;">0.022044 </td><td style="text-align: right;">0.112691</td><td style="text-align: right;">  0.0897612</td></tr>
# <tr><td>GBM_5_AutoML_20210513_234908                       </td><td style="text-align: right;">               0.0221303</td><td style="text-align: right;">0.148762</td><td style="text-align: right;">0.0221303</td><td style="text-align: right;">0.114066</td><td style="text-align: right;">  0.0901072</td></tr>
# <tr><td>GBM_2_AutoML_20210513_234908                       </td><td style="text-align: right;">               0.0221818</td><td style="text-align: right;">0.148936</td><td style="text-align: right;">0.0221818</td><td style="text-align: right;">0.114009</td><td style="text-align: right;">  0.0900685</td></tr>
# <tr><td>GBM_3_AutoML_20210513_234908                       </td><td style="text-align: right;">               0.0222146</td><td style="text-align: right;">0.149046</td><td style="text-align: right;">0.0222146</td><td style="text-align: right;">0.113839</td><td style="text-align: right;">  0.0901196</td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20210513_234908_model_3     </td><td style="text-align: right;">               0.0224005</td><td style="text-align: right;">0.149668</td><td style="text-align: right;">0.0224005</td><td style="text-align: right;">0.113889</td><td style="text-align: right;">  0.0905583</td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20210513_234908_model_10    </td><td style="text-align: right;">               0.0227335</td><td style="text-align: right;">0.150776</td><td style="text-align: right;">0.0227335</td><td style="text-align: right;">0.115138</td><td style="text-align: right;">  0.0912193</td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20210513_234908_model_2     </td><td style="text-align: right;">               0.0228   </td><td style="text-align: right;">0.150997</td><td style="text-align: right;">0.0228   </td><td style="text-align: right;">0.114859</td><td style="text-align: right;">  0.0911923</td></tr>
# <tr><td>GBM_grid__1_AutoML_20210513_234908_model_2         </td><td style="text-align: right;">               0.022845 </td><td style="text-align: right;">0.151145</td><td style="text-align: right;">0.022845 </td><td style="text-align: right;">0.116263</td><td style="text-align: right;">  0.0913192</td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20210513_234908_model_12    </td><td style="text-align: right;">               0.0228578</td><td style="text-align: right;">0.151188</td><td style="text-align: right;">0.0228578</td><td style="text-align: right;">0.115292</td><td style="text-align: right;">  0.0914384</td></tr>
# <tr><td>GBM_1_AutoML_20210513_234908                       </td><td style="text-align: right;">               0.0231039</td><td style="text-align: right;">0.152   </td><td style="text-align: right;">0.0231039</td><td style="text-align: right;">0.117243</td><td style="text-align: right;">  0.0919557</td></tr>
# <tr><td>DRF_1_AutoML_20210513_234908                       </td><td style="text-align: right;">               0.0232065</td><td style="text-align: right;">0.152337</td><td style="text-align: right;">0.0232065</td><td style="text-align: right;">0.118253</td><td style="text-align: right;">  0.0922939</td></tr>
# <tr><td>XRT_1_AutoML_20210513_234908                       </td><td style="text-align: right;">               0.0233115</td><td style="text-align: right;">0.152681</td><td style="text-align: right;">0.0233115</td><td style="text-align: right;">0.118943</td><td style="text-align: right;">  0.092508 </td></tr>
# <tr><td>GBM_grid__1_AutoML_20210513_234908_model_9         </td><td style="text-align: right;">               0.0235126</td><td style="text-align: right;">0.153338</td><td style="text-align: right;">0.0235126</td><td style="text-align: right;">0.119118</td><td style="text-align: right;">  0.0929878</td></tr>
# <tr><td>GBM_grid__1_AutoML_20210513_234908_model_6         </td><td style="text-align: right;">               0.0236456</td><td style="text-align: right;">0.153771</td><td style="text-align: right;">0.0236456</td><td style="text-align: right;">0.119291</td><td style="text-align: right;">  0.0932857</td></tr>
# <tr><td>DeepLearning_grid__2_AutoML_20210513_234908_model_1</td><td style="text-align: right;">               0.0237182</td><td style="text-align: right;">0.154007</td><td style="text-align: right;">0.0237182</td><td style="text-align: right;">0.111462</td><td style="text-align: right;">nan        </td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20210513_234908_model_14    </td><td style="text-align: right;">               0.0238073</td><td style="text-align: right;">0.154296</td><td style="text-align: right;">0.0238073</td><td style="text-align: right;">0.117537</td><td style="text-align: right;">  0.0931599</td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20210513_234908_model_11    </td><td style="text-align: right;">               0.0240296</td><td style="text-align: right;">0.155015</td><td style="text-align: right;">0.0240296</td><td style="text-align: right;">0.117193</td><td style="text-align: right;">  0.0935124</td></tr>
# <tr><td>GBM_grid__1_AutoML_20210513_234908_model_5         </td><td style="text-align: right;">               0.0240641</td><td style="text-align: right;">0.155126</td><td style="text-align: right;">0.0240641</td><td style="text-align: right;">0.120782</td><td style="text-align: right;">  0.0939177</td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20210513_234908_model_15    </td><td style="text-align: right;">               0.0242625</td><td style="text-align: right;">0.155764</td><td style="text-align: right;">0.0242625</td><td style="text-align: right;">0.118088</td><td style="text-align: right;">  0.0939582</td></tr>
# <tr><td>GBM_grid__1_AutoML_20210513_234908_model_3         </td><td style="text-align: right;">               0.0243198</td><td style="text-align: right;">0.155948</td><td style="text-align: right;">0.0243198</td><td style="text-align: right;">0.119312</td><td style="text-align: right;">  0.0943585</td></tr>
# <tr><td>XGBoost_3_AutoML_20210513_234908                   </td><td style="text-align: right;">               0.0245287</td><td style="text-align: right;">0.156616</td><td style="text-align: right;">0.0245287</td><td style="text-align: right;">0.121259</td><td style="text-align: right;">  0.0950513</td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20210513_234908_model_6     </td><td style="text-align: right;">               0.0245898</td><td style="text-align: right;">0.156811</td><td style="text-align: right;">0.0245898</td><td
#
#
# Leader:  Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_AutoML_20210513_234908
#
# No model summary for this model
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.005140302416036697
# RMSE: 0.07169590236573284
# MAE: 0.05183665274045402
# RMSLE: 0.04340317684694182
# R^2: 0.9094517237881498
# Mean Residual Deviance: 0.005140302416036697
# Null degrees of freedom: 10042
# Residual degrees of freedom: 10025
# Null deviance: 570.12817717749
# Residual deviance: 51.62405716425654
# AIC: -24394.271941175077
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.020479127613452837
# RMSE: 0.14310530253436746
# MAE: 0.10683263247517613
# RMSLE: 0.08995702050309032
# R^2: 0.6386652323004279
# Mean Residual Deviance: 0.020479127613452837
# Null degrees of freedom: 10693
# Residual degrees of freedom: 10678
# Null deviance: 606.2214683827049
# Residual deviance: 219.00379069826462
# AIC: -11199.747678235204
#
#
# --- 2669.450325012207 seconds ---
# 0.7415142010980182 hours training.

# %%
save_aml_models(aml)
# Out:
# Model StackedEnsemble_AllModels_AutoML_20201223_115349 saved.
# Model StackedEnsemble_BestOfFamily_AutoML_20201223_115349 saved.
# Model GBM_3_AutoML_20201223_115349 saved.
# Model GBM_4_AutoML_20201223_115349 saved.
# Model DeepLearning_grid__3_AutoML_20201223_115349_model_3 saved.
# Model GBM_2_AutoML_20201223_115349 saved.
# Model GBM_grid__1_AutoML_20201223_115349_model_2 saved.
# Model GBM_1_AutoML_20201223_115349 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_14 saved.
# Model XRT_1_AutoML_20201223_115349 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_3 saved.
# Model DRF_1_AutoML_20201223_115349 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_16 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_10 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_5 saved.
# Model GBM_5_AutoML_20201223_115349 saved.
# Model GBM_grid__1_AutoML_20201223_115349_model_3 saved.
# Model GBM_grid__1_AutoML_20201223_115349_model_7 saved.
# Model DeepLearning_grid__3_AutoML_20201223_115349_model_1 saved.
# Model GBM_grid__1_AutoML_20201223_115349_model_5 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_2 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_17 saved.
# Model DeepLearning_grid__3_AutoML_20201223_115349_model_2 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_1 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_11 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_7 saved.
# Model GBM_grid__1_AutoML_20201223_115349_model_8 saved.
# Model GBM_grid__1_AutoML_20201223_115349_model_10 saved.
# Model GBM_grid__1_AutoML_20201223_115349_model_6 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_12 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_9 saved.
# Model XGBoost_3_AutoML_20201223_115349 saved.
# Model GBM_grid__1_AutoML_20201223_115349_model_9 saved.
# Model GBM_grid__1_AutoML_20201223_115349_model_1 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_13 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_15 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_4 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_6 saved.
# Model DeepLearning_grid__2_AutoML_20201223_115349_model_2 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_18 saved.
# Model GBM_grid__1_AutoML_20201223_115349_model_4 saved.
# Model XGBoost_grid__1_AutoML_20201223_115349_model_8 saved.
# Model XGBoost_1_AutoML_20201223_115349 saved.
# Model XGBoost_2_AutoML_20201223_115349 saved.
# Model DeepLearning_grid__2_AutoML_20201223_115349_model_3 saved.
# Model DeepLearning_grid__2_AutoML_20201223_115349_model_1 saved.
# Model DeepLearning_grid__1_AutoML_20201223_115349_model_4 saved.
# Model DeepLearning_1_AutoML_20201223_115349 saved.
# Model DeepLearning_grid__1_AutoML_20201223_115349_model_3 saved.
# Model GLM_1_AutoML_20201223_115349 saved.
# Model DeepLearning_grid__1_AutoML_20201223_115349_model_2 saved.
# Model DeepLearning_grid__1_AutoML_20201223_115349_model_1 saved.

# %% [markdown]
# ### Making predictions.

# %%
best_model = h2o.import_mojo('../../models/mojo_50_ensemble/StackedEnsemble_AllModels_AutoML_20201223_115349.zip')
preds, len_train, len_validation = gen_predictions(df, best_model)
# Out:
# generic Model Build progress: |███████████████████████████████████████████| 100%
# Model Details
# =============
# H2OGenericEstimator :  Import MOJO Model
# Model Key:  Generic_model_python_1608734123823_106
#
# No model summary for this model
#
# ModelMetricsRegressionGeneric: generic
# ** Reported on train data. **
#
# MSE: 0.0029843621318644473
# RMSE: 0.0546293156818246
# MAE: 0.04095889497837518
# RMSLE: 0.030993632001274172
# Mean Residual Deviance: 0.0029843621318644473
#
# ModelMetricsRegressionGeneric: generic
# ** Reported on cross-validation data. **
#
# MSE: 0.007612769296751577
# RMSE: 0.0872511850736228
# MAE: 0.06616340247814928
# RMSLE: 0.05020608420962501
# Mean Residual Deviance: 0.007612769296751577
#
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# generic prediction progress: |████████████████████████████████████████████| 100%
#
#  2550 train/test objects
#  and 2528 validation objects

# %% [markdown]
# ### Manual RMSE verification

# %%
pd_preds = preds.as_data_frame()['predict'].tolist()
true_y = list(df.iloc[-len_validation:].loc[:,'REDSHIFT_SPEC'])
RMSE = (mean_squared_error(list(df.iloc[-len_validation:].loc[:,'REDSHIFT_SPEC']), pd_preds))**(1/2)
RMSE
# Out:
# 0.07370475020616392

# %% [markdown]
# ### ANS: Values don't match exactly with leaderboard RMSE Score ( 0.0836604	). However SckiKit external score reachs an even lower value. Approved and Verified.
#
# #### Edit: Value was lower due to absence of seed set when the 50 models were trained.
