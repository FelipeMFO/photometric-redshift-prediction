# %%
import pandas as pd
import numpy as np

import pickle

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel

# %%
import pandavro as pdx

# %%
df1 = pd.read_pickle("df_GP_scikit_desr.pkl")

# %%
df1[['desi_GP','desr_GP']].to_pickle("./desi_desr.pkl")

# %%
desi_desr = pd.read_pickle("desi_desr.pkl")

# %%
desi_desr
# Out:
#                                                  desi_GP  \
# 0      ([0.03200000000651926, 1.4642525252590228, 2.8...
# 1      ([0.010999999998603016, 1.253707070705658, 2.4...
# 2      ([4.105999999999767, 5.236050505050272, 6.3661...
# 3      ([0.031000000002677552, 1.6152424242450665, 3....
# 4      ([0.023999999997613486, 1.3862121212097753, 2....
# ...                                                  ...
# 21312  ([0.01599999999598367, 1.0764848484808809, 2.1...
# 21313  ([0.031000000002677552, 1.0211010101036553, 2....
# 21314  ([12.984000000004016, 13.628808080812053, 14.2...
# 21315  ([0.027000000001862645, 1.269262626264456, 2.5...
# 21316  ([0.0, 0.9276363636363202, 1.8552727272726404,...
#
#                                                  desr_GP
# 0      ([2.0, 3.412292929292957, 4.824585858585914, 6...
# 1      ([0.004000000000814907, 1.24669696969773, 2.48...
# 2      ([0.008000000001629815, 1.1792828282844798, 2....
# ...

# %%
pdx.to_avro('desi_desr.avro', desi_desr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-9b400bd84eba> in <module>
# ----> 1 pdx.to_avro('desi_desr.avro', desi_desr)
#
# ~/.local/lib/python3.6/site-packages/pandavro/__init__.py in to_avro(file_path_or_buffer, df, schema, codec, append)
#     149         with open(file_path_or_buffer, open_mode) as f:
#     150             fastavro.writer(f, schema=schema,
# --> 151                             records=df.to_dict('records'), codec=codec)
#     152     else:
#     153         fastavro.writer(file_path_or_buffer, schema=schema,
#
# fastavro/_write.pyx in fastavro._write.writer()
#
# fastavro/_write.pyx in fastavro._write.Writer.write()
#
# fastavro/_write.pyx in fastavro._write.write_data()
#
# fastavro/_write.pyx in fastavro._write.write_record()
#
# fastavro/_write.pyx in fastavro._write.write_data()
#
# ...

# %%
df2 = pd.read_pickle("df_GP_scikit_desz.pkl")

# %%
df2
# Out:
#              ID                                               desg  \
# 0      SN554563  [[0.0, 18.98, 10.49], [1.985000000000582, 0.89...
# 1      SN454964  [[0.0, 4.359, 6.2], [4.9799999999959255, 33.82...
# 2      SN537864  [[0.0, 0.4987, 4.764], [11.969000000004598, 8....
# 3      SN528418  [[0.0, 4.402, 4.787], [2.0, 4.78, 2.24], [11.9...
# 4       SN11302  [[0.0, 7.765, 4.769], [2.997000000003027, 3.75...
# ...         ...                                                ...
# 21312  SN538509  [[2.989000000001397, 2.453, 2.589], [4.0670000...
# 21313  SN710827  [[0.0, 11.09, 4.807], [2.0, 14.44, 2.281], [9....
# 21314   SN51813  [[14.859000000004016, 11.64, 11.89], [30.91799...
# 21315  SN599115  [[0.0, 3.229, 7.693], [10.014999999999418, 1.1...
# 21316  SN308423  [[29.875, 4.829, 11.89], [53.88699999999517, 9...
#
#                                                     desi  \
# 0      [[0.03200000000651926, 8.001, 9.313], [10.9610...
# ...

# %%
#df_all = 
pd.concat([df2,desi_desr], axis=1).to_pickle("./df_GP_all.pkl")
