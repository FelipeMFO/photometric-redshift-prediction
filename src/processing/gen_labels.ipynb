# %%
# %run ../functions.ipynb

# %%
import os
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = 6

# %% [markdown]
# ## Getting raw data and type_bool (IA or not IA)

# %%
path_to_read = '../../data/raw/'
files = []

# r=root, d=directories, f = files
for r, d, f in os.walk(path_to_read):
    for file in f:
        if '.DAT' in file:
            files.append(os.path.join(r, file))

# %%
df = pd.DataFrame(columns = ['ID', 'type'])
for i, obj in enumerate(files):
    ID, tp = get_label(obj)
    df.loc[i] = [ID, tp]
df['type_bool'] = False 
df['type_bool'].loc[np.where(df['type'] == 'Ia')] = True
#df.to_pickle("../../data/df_labels.pkl")
# Out:
# /home/fmoliveira/.local/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df
# Out:
#              ID type  type_bool
# 0      SN125764  IIn      False
# 1      SN513286   Ic      False
# 2      SN501595   II      False
# ...         ...  ...        ...
# 21314  SN789717   Ic      False
# 21315  SN147538   II      False
# 21316   SN52860   II      False
#
# [21317 rows x 3 columns]

# %%
#df_label = pd.read_pickle("../../data/df_labels.pkl")
df_label
# Out:
#              ID type  type_bool
# 0      SN554563   II      False
# 1      SN454964   II      False
# 2      SN537864   II      False
# 3      SN528418   II      False
# ...         ...  ...        ...
# 21313  SN710827   II      False
# 21314   SN51813   Ia       True
# 21315  SN599115   II      False
# 21316  SN308423   Ib      False
#
# [21317 rows x 3 columns]

# %% [markdown]
# ## Getting Redshift

# %%
zspec = pd.read_csv("../../data/zspec.csv")
zpsec.columns = ['ID', 'REDSHIFT_SPEC']
zspec['ID'] = 'SN' + zspec['ID'].astype(str)
zspec
# Out:
#              ID  REDSHIFT_SPEC
# 0      SN555557        0.89174
# 1      SN119309        0.30850
# 2      SN600220        0.63943
# 3      SN419675        0.92712
# 4      SN485017        0.88103
# 5      SN253020        0.29424
# 6      SN868147        0.91414
# 7      SN517063        0.65154
# 8       SN84987        0.19953
# 9      SN212098        0.66477
# 10     SN851279        0.86884
# 11     SN845340        0.87028
# 12     SN851344        0.67261
# 13      SN79220        0.72343
# 14     SN449600        0.92522
# 15     SN393894        0.81381
# 16     SN448036        0.16692
# 17       SN8904        0.84507
# 18     SN851555        0.90785
# 19     SN818859        1.03175
# 20     SN634432        0.77139
# 21      SN66171        0.44487
# 22     SN241832        1.02499
# 23     SN233641        0.57271
# 24     SN594556        0.21510
# 25     SN106310        0.95657
# 26     SN636092        0.67457
# 27     SN769696        0.31466
# 28     SN674381        0.54630
# ...

# %%
df_redshift = pd.concat([df_label.set_index('ID'), zspec.set_index('ID')], axis = 1 , join = "inner", sort = 'True')
df_redshift.to_pickle("../../data/df_redshift.pkl")
